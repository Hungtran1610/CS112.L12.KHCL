# %% [markdown]
# ## **Đề bài**
#
# <p style="text-align:justify">Để tăng độ an to&agrave;n chống hiện tượng cướp ng&acirc;n h&agrave;ng ng&agrave;y c&agrave;ng phổ biến người ta d&ugrave;ng kh&oacute;a số với m&atilde; mở kh&oacute;a đơn giản nhưng rất hiệu quả. Tr&ecirc;n cửa ra v&agrave;o hiển thị một x&acirc;u kh&aacute; d&agrave;i c&aacute;c k&yacute; tự số. C&aacute;c chữ số c&oacute; thể di chuyển đổi chổ cho nhau hoặc bị x&oacute;a. Muốn mở kh&oacute;a người ta phải di chuyển c&aacute;c chữ số v&agrave; trong trường hợp cần thiết &ndash; x&oacute;a v&agrave;i chữ số để nhận được <em>x&acirc;u lớn nhất</em> thỏa m&atilde;n điều kiện đ&atilde; c&agrave;i đặt. Điều kiện n&agrave;y được thay đổi thường xuy&ecirc;n. H&ocirc;m nay điều kiện đ&oacute; l&agrave; &ldquo;Số nhận được phải chia hết cho 3&rdquo;. Số nhận được c&oacute; thể bắt đầu bằng c&aacute;c chữ số 0. X&acirc;u &ldquo;000&rdquo; sẽ lớn hơn x&acirc;u &ldquo;00&rdquo;.</p>
#
# <p style="text-align:justify">H&atilde;y x&aacute;c định kh&oacute;a mở cửa.</p>
#
# <p style="text-align:justify"><strong><em><span style="color:black">Dữ liệu:</span></em></strong> V&agrave;o từ thiết bị nhập chuẩn gồm một x&acirc;u k&yacute; tự số c&oacute; độ d&agrave;i lớn hơn 2 v&agrave; kh&ocirc;ng vượt qu&aacute; 10<sup>5</sup>.</p>
#
# <p style="text-align:justify"><strong><em><span style="color:black">Kết quả:</span></em></strong> Đưa ra thiết bị xuất chuẩn x&acirc;u kh&oacute;a mở cửa<span style="color:black">.</span></p>
#
# <p style="text-align:justify"><strong><em><span style="color:black">V&iacute; dụ:</span></em></strong></p>
#
# <table border="1" cellspacing="0">
# 	<tbody>
# 		<tr>
# 			<td style="background-color:#ffffcc; width:63.0pt">
# 			<p style="text-align:justify"><tt><span style="color:black">INPUT</span></tt></p>
# 			</td>
# 			<td style="background-color:#ffffcc; width:67.5pt">
# 			<p style="text-align:justify"><tt><span style="color:black">OUTPUT</span></tt></p>
# 			</td>
# 		</tr>
# 		<tr>
# 			<td style="background-color:#ffffcc; width:63.0pt">
# 			<p style="text-align:justify"><tt><strong><span style="color:black">105</span></strong></tt></p>
# 			</td>
# 			<td style="background-color:#ffffcc; width:67.5pt">
# 			<p style="text-align:justify"><tt><strong><span style="color:black">510</span></strong></tt></p>
# 			</td>
# 		</tr>
# 	</tbody>
# </table>
#
# <p style="text-align:justify">&nbsp;</p>
#
#
# # Tóm tắt
#
# Tìm dãy con tạo thành một số *lớn nhất* chia hết cho 3
#
# # Nhận dạng
# Đây là bài toán *chia để trị* . Ta có thể thấy toán gồm 2 bài toán con là tìm dãy chia hết cho 3 và sắp xếp giảm dần dãy đó.
#
# # Thiết kế thuật toán
# **1. Ý TƯỞNG:**
#
# **_Trường hợp 1:_**  tổng các số trong dãy đều chia hết cho 3.
#
# Ví dụ:
#
# Input:`21080412`
# output:`84221100`
#
# - Lần lượt tách và thực hiện cộng các số hạng trong dãy (sum). Ở đây ta có thể tính $ 2+1+0+8+0+4+1+2=18 $ chia hết cho 3.
# - Sắp xếp dãy số này từ lớn đến bé (giảm dần).
#
# **_Trường hợp 2:_**  tổng các số trong dãy không chia hết cho 3.
#
# Ví dụ:
#
# Input:`210804122`
# output:`84221100`
#
# - Lần lượt tách và thực hiện cộng các số hạng trong dãy. Ở đây ta có thể tính $ 2+1+0+8+0+4+1+2+2=20 $ chia cho 3 dư 2.
# - do x là 2 và 2 là phần tử trong dãy => Loại 2.
# - Sắp xếp dãy số còn lại từ lớn đến bé (giảm dần).
#
#
# **_Trường hợp 3:_**  tổng các số trong dãy không chia hết cho $ 3 $ và số dư $ x $ không tồn tại trong dãy.
#
# Input:`39226`
# Output: `9630`
#
# Input: `631649`
# Output: `9663`
#
# Trong ví dụ 1: 39226 % 3 = 1, Output đã bỏ đi 2 số 2
#
# Trong ví dụ 2: 631649 % 3 = 2, Output đã bỏ đi 1 và 4
#
# - Ta nhận thấy 4 % 3 = 1, 5 % 3 = 2. Tổng 2 chữ số % 3 = 1 sẽ là 1 số % 3 = 2, và ngược lại.
#
#
# # Thuật toán:
#
# * luồn xử lí
#
# ```
# B1: kiểm tra dãy số có chia hết cho 3 hay không.
#         B1 -> có -> B5
#         B1 -> không -> B2
#
# B2: tìm vị trí a[i] = x. Nếu không thấy trả về -1.
#         B2 -> có -> B4
#         B2 -> không -> B3
#
# B3: tìm vị trí a[i] % 3 = x, a[j] % 3 = x. Nếu không thấy trả về -1.
#         B3 -> có -> B4
#
# B4: Xóa vị trí đó -> B5
#
# B5: sắp xếp lại dãy giảm dần, in dãy và thoát.
# ```
#
# * mã giả:
#
# ```
# init input_number
#
# if input_number % 3 == 0 then
#     output
#     exit
#
# x <- input_number % 3
# input_number_to_string <- str(input_number)
#
# if x in input_number then
#     i <- find_index_of_unfit_number(x)
#     if i <> -1 then
#         delete input_number_to_string[i]
#     if i <> -1 then
#         index1, index2 = find_two_index_of_unfit_number(x)
#         if index1 <> 0 and index2 <> 0 then
#             delete input_number_to_string[index1]
#             delete input_number_to_string[index2]
# ```
#
# # Cài đặt

# %%
s = input()
list_a = list(s)
int_s = int(s)
list_a.sort()

# TH1: Nếu dãy chia hết cho 3 thì sắp xếp dãy giảm gần, in dãy -> thoát
if int_s % 3 == 0:
    list_a.reverse()
    print(''.join(list_a))
    exit()

x = int(int_s % 3)

# tìm i trong a sao cho a[i] % 3 = x, nếu không trả về -1
def senario_one(input_string, x):
    ind_result = -1
    if str(x) in input_string:
        ind_result = input_string.index(str(x))
        return ind_result
    
    if str(x + 3) in input_string:
        ind_result = input_string.index(str(x + 3))
        return ind_result
    
    if str(x + 6) in input_string:
        ind_result = input_string.index(str(x + 6))
        return ind_result

    return ind_result

# tìm vị trí i, j trong a sao cho a[i] % 3 = x, a[j] % 3 = x, nếu không trả về -1, -1
def senario_two(input_string, x):
    first_index = senario_one(input_string, x)
    second_index = senario_one(input_string[first_index + 1: ], x) + first_index + 1
    return first_index, second_index

# Tìm và xóa vị trí không thỏa mãn điều kiện, sắp xếp lại dãy giảm dần, in dãy
ind = senario_one(list_a, x)
if ind == -1:
    ind_1, ind_2 = senario_two(list_a, (x*2)%3)
    if ind_1 != -1 and ind_2 != -1:
        list_a.remove(list_a[ind_1])
        list_a.remove(list_a[ind_2 - 1])

        list_a.reverse()

        if len(list_a) == 1:
            print(str(list_a[0]))
            exit()
        else:
            print(''.join(list_a))
            exit()

list_a.remove(list_a[ind])
list_a.reverse()
if list_a != []:
    print(''.join(list_a))
    exit()
# Out:
# 631649
# 9664
# 966

# %% [markdown]
# # cải tiến:
#
# Để dễ kiểm soát, ta nhận thấy các số giới hạn từ từ 1 đến 9 nên ta dễ dàng phân chúng vào thành 3 nhóm.
#
# - Những số chia cho 3 dư 0 = {3, 6, 9}
# - Những số chia cho 3 dư 1 = {1, 4, 7}
# - Nhưng số chia cho 3 dư 2 = {2, 5, 8}
#
# ta đặt giả thuyết ở đây là bằng một cách nào đó ta có thể vận dụng quy tắc này để hard code phần tìm kiếm ở senario_one giúp tăng tốc khả năng chạy của chương trình.
